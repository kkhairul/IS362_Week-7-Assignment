# %%
import numpy as np
import pandas as pd
#set some pandas options controling output format
pd.set_option('display.notebook_repr_html',True) # output as flat text and not HTML
pd.set_option('display.max_rows', None) # this is the maximum number of rows we will display
pd.set_option('display.max_columns', None) # this is the maximum number of rows we will display

# bring in matplotlib for graphics
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 1. Load the ratings by user information that you collected into a pandas dataframe.
# read the CSV into a dataframe
ratings = pd.read_csv('MOVIES.csv', index_col=0)
ratings.head()  # take a peak at the date.
# Out:
#                     SIMON  Adia  Eddie  Jabari  TOM  Taline  Matt  Salman  \
# Extraction            4.0   NaN    3.0     NaN  NaN     NaN   4.0     NaN
# Bad Boys for Life     4.0   NaN    5.0     NaN  2.0     4.0   4.0     4.0
# Sonic the Hedgehog    NaN   NaN    2.0     NaN  NaN     4.0   3.0     NaN
# Bloodshot             2.0   1.0    3.0     NaN  NaN     1.0   1.0     NaN
# Trolls World Tour     NaN   4.0    1.0     4.0  4.0     NaN   NaN     NaN
#
#                     Anthony  Sahara  Kaamil  KHAIRUL
# Extraction              4.0     NaN     NaN      NaN
# Bad Boys for Life       NaN     5.0     5.0      5.0
# Sonic the Hedgehog      NaN     NaN     4.0      5.0
# Bloodshot               NaN     2.0     NaN      NaN
# Trolls World Tour       NaN     NaN     2.0      NaN

# %%
# 2.a. Show the average ratings for each USER
# Calculate the average by column
ratings.mean()
# Out:
# SIMON      3.000000
# Adia       2.750000
# Eddie      3.000000
# Jabari     3.000000
# TOM        2.600000
# Taline     3.375000
# Matt       2.700000
# Salman     3.333333
# Anthony    3.500000
# Sahara     2.750000
# Kaamil     3.800000
# KHAIRUL    4.250000
# dtype: float64

# %%
# 2.b. Show the average ratings for each MOVIE
# Calculate the average by row 
rmean = pd.Series(ratings.mean(axis=1))
rmean
# Out:
# Extraction            3.750000
# Bad Boys for Life     4.222222
# Sonic the Hedgehog    3.600000
# Bloodshot             1.666667
# Trolls World Tour     3.000000
# The Platform          2.000000
# Code 8                3.400000
# The Gentlemen         3.500000
# Frozen 2              2.777778
# Underwater            2.500000
# The Invisible Man     3.500000
# dtype: float64

# %%
# 3.a. Create a new pandas dataframe, with normalized ratings for each user. Again, show
#      the average ratings for each user and each movie.
# To calculate this I will be using the following formula mentioned in this post:
#      http://bi-analytics.org/topic/9-standardization-vs-normalization/
# The formula is as follows:
#      Xnew = (X-Xmin) / (Xmax - Xmin
# Calculate the normalized ratings for each cell. And transpose the rows and columns
ratings_norm = ((ratings - ratings.min()) / (ratings.max() - ratings.min())).transpose()
ratings_norm    # Display the dataframe
# Out:
#          Extraction  Bad Boys for Life  Sonic the Hedgehog  Bloodshot  \
# SIMON           1.0           1.000000                 NaN       0.00
# Adia            NaN                NaN                 NaN       0.00
# Eddie           0.5           1.000000            0.250000       0.50
# Jabari          NaN                NaN                 NaN        NaN
# TOM             NaN           0.333333                 NaN        NaN
# Taline          NaN           1.000000            1.000000       0.00
# Matt            1.0           1.000000            0.666667       0.00
# Salman          NaN           1.000000                 NaN        NaN
# Anthony         1.0                NaN                 NaN        NaN
# Sahara          NaN           1.000000                 NaN       0.25
# Kaamil          NaN           1.000000            0.666667        NaN
# KHAIRUL         NaN           1.000000            1.000000        NaN
#
#          Trolls World Tour  The Platform    Code 8  The Gentlemen  Frozen 2  \
# SIMON                  NaN           NaN       NaN            NaN  0.500000
# Adia                   1.0           NaN       NaN            NaN  0.666667
# Eddie                  0.0           NaN       NaN            NaN  0.500000
# Jabari                 1.0      0.000000       NaN            NaN       NaN
# TOM                    1.0      0.333333  1.000000            NaN  0.000000
# Taline                 NaN      0.666667  1.000000       1.000000       NaN
# Matt                   NaN      0.333333  0.333333       0.666667  0.666667
# Salman                 NaN           NaN       NaN            NaN  0.000000
# Anthony                NaN           NaN  0.000000            NaN  1.000000
# Sahara                 NaN      0.000000       NaN            NaN  0.500000
# Kaamil                 0.0           NaN  0.666667            NaN       NaN
# KHAIRUL                NaN           NaN       NaN            NaN  0.000000
#
#          Underwater  The Invisible Man
# SIMON      0.000000           0.500000
# Adia            NaN           0.666667
# Eddie      0.500000           0.750000
# Jabari          NaN           0.500000
# TOM             NaN                NaN
# Taline     0.666667           1.000000
# Matt       0.333333           0.666667
# Salman          NaN           0.000000
# Anthony         NaN           0.000000
# Sahara          NaN                NaN
# Kaamil          NaN           0.666667
# KHAIRUL         NaN           1.000000

# %%
# 3.b. Show the average NORMALIZED ratings for each USER
# Calculate the average of the normalized ratings by row.
ratings_norm.mean(axis=1)
# Out:
# SIMON      0.500000
# Adia       0.583333
# Eddie      0.500000
# Jabari     0.500000
# TOM        0.533333
# Taline     0.791667
# Matt       0.566667
# Salman     0.333333
# Anthony    0.500000
# Sahara     0.437500
# Kaamil     0.600000
# KHAIRUL    0.750000
# dtype: float64

# %%
# 3.c. Show the average NORMALIZED ratings for each MOVIE
# Calculate the average of the normalized ratings by column.
rnorm = pd.Series(ratings_norm.mean())
rnorm
# Out:
# Extraction            0.875000
# Bad Boys for Life     0.925926
# Sonic the Hedgehog    0.716667
# Bloodshot             0.125000
# Trolls World Tour     0.600000
# The Platform          0.266667
# Code 8                0.600000
# The Gentlemen         0.833333
# Frozen 2              0.425926
# Underwater            0.375000
# The Invisible Man     0.575000
# dtype: float64

# %%
# create a dataframe with both the average and normalized series by movie.
ratings_averages = pd.DataFrame({'mean':rmean, 'norm':rnorm},rmean.index)
ratings_averages
# Out:
#                         mean      norm
# Extraction          3.750000  0.875000
# Bad Boys for Life   4.222222  0.925926
# Sonic the Hedgehog  3.600000  0.716667
# Bloodshot           1.666667  0.125000
# Trolls World Tour   3.000000  0.600000
# The Platform        2.000000  0.266667
# Code 8              3.400000  0.600000
# The Gentlemen       3.500000  0.833333
# Frozen 2            2.777778  0.425926
# Underwater          2.500000  0.375000
# The Invisible Man   3.500000  0.575000

# %%
# Sort the movies by the AVERAGE rating
ratings_averages.sort_values('mean',ascending=False)
# Out:
#                         mean      norm
# Bad Boys for Life   4.222222  0.925926
# Extraction          3.750000  0.875000
# Sonic the Hedgehog  3.600000  0.716667
# The Gentlemen       3.500000  0.833333
# The Invisible Man   3.500000  0.575000
# Code 8              3.400000  0.600000
# Trolls World Tour   3.000000  0.600000
# Frozen 2            2.777778  0.425926
# Underwater          2.500000  0.375000
# The Platform        2.000000  0.266667
# Bloodshot           1.666667  0.125000

# %%
# Sort the movies by the NORMALIZED average rating
ratings_averages.sort_values('norm',ascending=False)
# Out:
#                         mean      norm
# Bad Boys for Life   4.222222  0.925926
# Extraction          3.750000  0.875000
# The Gentlemen       3.500000  0.833333
# Sonic the Hedgehog  3.600000  0.716667
# Trolls World Tour   3.000000  0.600000
# Code 8              3.400000  0.600000
# The Invisible Man   3.500000  0.575000
# Frozen 2            2.777778  0.425926
# Underwater          2.500000  0.375000
# The Platform        2.000000  0.266667
# Bloodshot           1.666667  0.125000

# %%
# 5.a. [Extra credit] Create another new pandas dataframe, with STANDARDIZED ratings for each user.
#      Once again, show the average ratings for each user and each movie.
# To calculate this I will be using the following formula mentioned in this post:
#      http://bi-analytics.org/topic/9-standardization-vs-normalization/
# The formula is as follows:
#      Xnew = (X-μ) / σ
# Calculate the normalized ratings for each cell. And transpose the rows and columns
ratings_stand = ((ratings - ratings.mean()) / (ratings.std())).transpose()
ratings_stand
# Out:
#          Extraction  Bad Boys for Life  Sonic the Hedgehog  Bloodshot  \
# SIMON      1.118034           1.118034                 NaN  -1.118034
# Adia            NaN                NaN                 NaN  -1.390759
# Eddie      0.000000           1.673320           -0.836660   0.000000
# Jabari          NaN                NaN                 NaN        NaN
# TOM             NaN          -0.447214                 NaN        NaN
# Taline          NaN           0.589256            0.589256  -2.239171
# Matt       1.370320           1.370320            0.316228  -1.791957
# Salman          NaN           1.154701                 NaN        NaN
# Anthony    0.866025                NaN                 NaN        NaN
# Sahara          NaN           1.317465                 NaN  -0.439155
# Kaamil          NaN           1.095445            0.182574        NaN
# KHAIRUL         NaN           0.500000            0.500000        NaN
#
#          Trolls World Tour  The Platform    Code 8  The Gentlemen  Frozen 2  \
# SIMON                  NaN           NaN       NaN            NaN  0.000000
# Adia              0.993399           NaN       NaN            NaN  0.198680
# Eddie            -1.673320           NaN       NaN            NaN  0.000000
# Jabari            1.000000     -1.000000       NaN            NaN       NaN
# TOM               1.043498     -0.447214  1.043498            NaN -1.192570
# Taline                 NaN     -0.353553  0.589256       0.589256       NaN
# Matt                   NaN     -0.737865 -0.737865       0.316228  0.316228
# Salman                 NaN           NaN       NaN            NaN -0.577350
# Anthony                NaN           NaN -0.866025            NaN  0.866025
# Sahara                 NaN     -1.024695       NaN            NaN  0.146385
# Kaamil           -1.643168           NaN  0.182574            NaN       NaN
# KHAIRUL                NaN           NaN       NaN            NaN -1.500000
#
#          Underwater  The Invisible Man
# SIMON     -1.118034           0.000000
# Adia            NaN           0.198680
# Eddie      0.000000           0.836660
# Jabari          NaN           0.000000
# TOM             NaN                NaN
# Taline    -0.353553           0.589256
# Matt      -0.737865           0.316228
# Salman          NaN          -0.577350
# Anthony         NaN          -0.866025
# Sahara          NaN                NaN
# Kaamil          NaN           0.182574
# KHAIRUL         NaN           0.500000

# %%
# 5.b. Show the average NORMALIZED ratings for each USER
# Calculate the average of the normalized ratings by row.
ratings_stand.mean(axis=1)
# Out:
# SIMON      0.000000e+00
# Adia       0.000000e+00
# Eddie      0.000000e+00
# Jabari     0.000000e+00
# TOM       -8.881784e-17
# Taline     0.000000e+00
# Matt      -1.998401e-16
# Salman    -2.960595e-16
# Anthony    0.000000e+00
# Sahara     6.938894e-18
# Kaamil     1.665335e-16
# KHAIRUL    0.000000e+00
# dtype: float64

# %%
# 5.C. Show the average NORMALIZED ratings for each MOVIE
# Calculate the average of the normalized ratings by column.
rstand = pd.Series(ratings_stand.mean())
rstand
# Out:
# Extraction            0.838595
# Bad Boys for Life     0.930147
# Sonic the Hedgehog    0.150280
# Bloodshot            -1.163179
# Trolls World Tour    -0.055918
# The Platform         -0.712665
# Code 8                0.042288
# The Gentlemen         0.452742
# Frozen 2             -0.193622
# Underwater           -0.552363
# The Invisible Man     0.118002
# dtype: float64

# %%
# Add the average standardized rating for each movie to the dataframe that already 
# contains the average and normamalized average movie rating.
ratings_averages['stand'] = rstand
ratings_averages
# Out:
#                         mean      norm     stand
# Extraction          3.750000  0.875000  0.838595
# Bad Boys for Life   4.222222  0.925926  0.930147
# Sonic the Hedgehog  3.600000  0.716667  0.150280
# Bloodshot           1.666667  0.125000 -1.163179
# Trolls World Tour   3.000000  0.600000 -0.055918
# The Platform        2.000000  0.266667 -0.712665
# Code 8              3.400000  0.600000  0.042288
# The Gentlemen       3.500000  0.833333  0.452742
# Frozen 2            2.777778  0.425926 -0.193622
# Underwater          2.500000  0.375000 -0.552363
# The Invisible Man   3.500000  0.575000  0.118002

# %%
# Sort the movies by the AVERAGE rating
ratings_averages.sort_values('mean',ascending=False)
# Out:
#                         mean      norm     stand
# Bad Boys for Life   4.222222  0.925926  0.930147
# Extraction          3.750000  0.875000  0.838595
# Sonic the Hedgehog  3.600000  0.716667  0.150280
# The Gentlemen       3.500000  0.833333  0.452742
# The Invisible Man   3.500000  0.575000  0.118002
# Code 8              3.400000  0.600000  0.042288
# Trolls World Tour   3.000000  0.600000 -0.055918
# Frozen 2            2.777778  0.425926 -0.193622
# Underwater          2.500000  0.375000 -0.552363
# The Platform        2.000000  0.266667 -0.712665
# Bloodshot           1.666667  0.125000 -1.163179

# %%
# Sort the movies by the NORMALIZED average rating
ratings_averages.sort_values('norm',ascending=False)
# Out:
#                         mean      norm     stand
# Bad Boys for Life   4.222222  0.925926  0.930147
# Extraction          3.750000  0.875000  0.838595
# The Gentlemen       3.500000  0.833333  0.452742
# Sonic the Hedgehog  3.600000  0.716667  0.150280
# Trolls World Tour   3.000000  0.600000 -0.055918
# Code 8              3.400000  0.600000  0.042288
# The Invisible Man   3.500000  0.575000  0.118002
# Frozen 2            2.777778  0.425926 -0.193622
# Underwater          2.500000  0.375000 -0.552363
# The Platform        2.000000  0.266667 -0.712665
# Bloodshot           1.666667  0.125000 -1.163179

# %%
# Sort the movies by the STANDARDIZED average rating
ratings_averages.sort_values('stand',ascending=False)
# Out:
#                         mean      norm     stand
# Bad Boys for Life   4.222222  0.925926  0.930147
# Extraction          3.750000  0.875000  0.838595
# The Gentlemen       3.500000  0.833333  0.452742
# Sonic the Hedgehog  3.600000  0.716667  0.150280
# The Invisible Man   3.500000  0.575000  0.118002
# Code 8              3.400000  0.600000  0.042288
# Trolls World Tour   3.000000  0.600000 -0.055918
# Frozen 2            2.777778  0.425926 -0.193622
# Underwater          2.500000  0.375000 -0.552363
# The Platform        2.000000  0.266667 -0.712665
# Bloodshot           1.666667  0.125000 -1.163179
